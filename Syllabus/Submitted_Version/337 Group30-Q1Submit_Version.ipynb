# %% [markdown]
# Group Member: Francis Ding, Jiaren Pan, Han Qin.

# %% [markdown]
# #Q1.
#
#
#     Read the data in your notebook and display the first 8 rows. How many columns and rows are there in this dataset? What are the column names?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go

df = pd.read_csv('nobel.csv')

# %%
df.iloc[:8]
# Out:
#    year                category                                      prize  \
# 0  1901               Chemistry               The Nobel Prize in Chemistry
# 1  1901              Literature              The Nobel Prize in Literature
# 2  1901                   Peace                      The Nobel Peace Prize
# 3  1901                   Peace                      The Nobel Peace Prize
# 4  1901                 Physics                 The Nobel Prize in Physics
# 5  1901  Physiology or Medicine  The Nobel Prize in Physiology or Medicine
# 6  1902               Chemistry               The Nobel Prize in Chemistry
# 7  1902              Literature              The Nobel Prize in Literature
#
#                                           motivation price_share  laureate_id  \
# 0  in recognition of the extraordinary services h...           1          160
# 1  in special recognition of his poetic compositi...           1          569
# 2  for his lifelong work for international peace ...      02-Jan          463
# 3  for his humanitarian efforts to help wounded s...      02-Jan          462
# 4  in recognition of the extraordinary services h...           1            1
# 5  for his work on serum therapy, especially its ...           1          293
# 6  in recognition of the extraordinary services h...           1          161
# 7  the greatest living master of the art of histo...           1          571
#
#   laureate_type                           full_name  birth_date  birth_city  \
# 0    Individual        Jacobus Henricus van 't Hoff  1852-08-30   Rotterdam
# 1    Individual                     Sully Prudhomme  1839-03-16       Paris
# 2    Individual                      Frédéric Passy  1822-05-20       Paris
# 3    Individual                   Jean Henry Dunant  1828-05-08      Geneva
# 4    Individual              Wilhelm Conrad Röntgen  1845-03-27      Lennep
# 5    Individual              Emil Adolf von Behring  1854-03-15    Hansdorf
# 6    Individual                Hermann Emil Fischer  1852-10-09  Euskirchen
# 7    Individual  Christian Matthias Theodor Mommsen  1817-11-30     Garding
#
#      birth_country gender   organization_name organization_city  \
# 0  the Netherlands   male   Berlin University            Berlin
# 1           France   male                 NaN               NaN
# 2           France   male                 NaN               NaN
# 3      Switzerland   male                 NaN               NaN
# 4          Prussia   male   Munich University            Munich
# 5          Prussia   male  Marburg University           Marburg
# 6          Prussia   male   Berlin University            Berlin
# 7        Schleswig   male                 NaN               NaN
#
#   organization_country  death_date      death_city death_country
# 0              Germany  01/03/1911          Berlin       Germany
# 1                  NaN  07/09/1907        Châtenay        France
# 2                  NaN  12/06/1912           Paris        France
# 3                  NaN  30/10/1910          Heiden   Switzerland
# 4              Germany  10/02/1923          Munich       Germany
# 5              Germany  31/03/1917         Marburg       Germany
# 6              Germany  15/07/1919          Berlin       Germany
# 7                  NaN  01/11/1903  Charlottenburg       Germany

# %% [markdown]
# #Analysis.
#
#
#             Though we only display 8 rows in this page using df.loc(:8), the dataset we're working on have a total rows of 989, and 18 columns. The columns are based on a variety of components, these are "year, category, prize, motivation, price_share, laureate_id, laureate_type, full_name, birth_date, birth_city, birth_country, gender, organization_name, organization_city, organization_country, death_date, death_city, death_country".

# %% [markdown]
# #Q2.
#
#     All of the first 8 winners were from Europe. But that was back in 1901. Looking at all winners in this data, which gender and which country is the most commonly represented? (For country, we will use the birth_country of the winner.)

# %%
df.groupby('birth_country')['full_name'].count().sort_values(ascending=False)
# Out:
# birth_country
# USA                        296
# United Kingdom              92
# Germany                     80
# France                      58
# Sweden                      30
#                           ...
# Crete                        1
# Pakistan                     1
# German-occupied Poland       1
# Peru                         1
# Java, Dutch East Indies      1
# Name: full_name, Length: 99, dtype: int64

# %%
df.groupby('gender')['full_name'].count().sort_values(ascending=False)
# Out:
# gender
# male      898
# female     61
# Name: full_name, dtype: int64

# %% [markdown]
# #Analysis.
#
# #From the data manipulated and grouped by Pandas,we found out that the country that has the Top Winners is United States, and the gender that has the most Winners is male.

# %% [markdown]
# #Q3.
#
#         For the dominant country that you found in question 2, calculate the proportions of winners from that country in each decade. Make some plots to visualize your results. In which decade did the proportion reach the highest?

# %%
## we wanted to make grouping easier, thus I'm making a decades tag to each winner by using the pandas datetime module.
## Otherwise, we'll have to grab each data and slice it as a representative of 10 and assign it back using tags.
## New solution: 
## 1. I used select index solution that arrange the steps in 10.
## 2. I've converted df['year'] into str first and then to datetime datatype because pandas can't convert dftype np.int64
## directly to datetime object.
## 3. I've setted column date(datetime dtype) as the index, and trace it using row expressions with the comparison of int values.

df['decades'] = (df['year']// 10)* 10
dfCounts = df.groupby(['decades'])['prize'].count().reset_index()
dfUSA = df[df['birth_country'] == 'USA']
countUSA = dfUSA.groupby(['decades'])['prize'].count().reset_index()
countUSA['portion'] = (countUSA['prize'] / dfCounts['prize'] *100).round(2)

# %%
x = countUSA['decades']
y = countUSA['portion']

plt.rcParams['axes.facecolor'] = '#FFFAF0'
plt.figure(figsize=(15, 6))
## a bunch of configuration for y-axis ##
plt.ylim(0,100)
plt.ylabel('%', labelpad=20, rotation=0, ha='right')


## a bunch o configuration for x-axis ##
plt.xticks(x)
plt.xlabel('Decades')
## Placing the % sign.
plt.gca().yaxis.set_label_coords(0, 1.02)

## Placing the labels for each coordinates.
for i in range(len(x)):
    plt.annotate('{:.2f}%'.format(y[i]), xy=(x[i], y[i]), xytext=(x[i], y[i] + 0.05), ha='center', va='bottom')

##Plotting.
plt.grid()
plt.plot(x, y, linestyle = 'dashed', color='red',)
plt.title('Winners of Nobel in each Decade')
plt.show()

# %% [markdown]
# #Analysis:
#
#                From the data extracted from scientist and by creating brand new dataframes and series, we've analyzed that in 2000, there's about almost half of amount of total Nobel prize winner is within the USA, 43.90%.

# %% [markdown]
# #Q4.
#
#     Is there any gender imbalance in this data? How significant is that? Calculate the proportion of female laureates in each decade. Visualize your results and discuss.

# %%
df4= df[df['laureate_type'] == 'Individual']
# df4['decades'] = (dfIndividual['year']//10) *10 this got an un-related warning because I already have decades in df.
countAll = df4.groupby('decades')['prize'].count().reset_index()

dfMale = df4[df4['gender'] == 'male']
dfFemale = df4[df4['gender'] == 'female']
countMale = dfMale.groupby('decades')['prize'].count().reset_index()
countMale['malePortion'] = countMale['prize'] / countAll['prize'] * 100
countMale['femalePortion'] = 100 - countMale['malePortion']
countMale
# Out:
#     decades  prize  malePortion  femalePortion
# 0      1900     53    94.642857       5.357143
# 1      1910     37    97.368421       2.631579
# 2      1920     52    96.296296       3.703704
# 3      1930     52    94.545455       5.454545
# 4      1940     37    92.500000       7.500000
# 5      1950     71   100.000000       0.000000
# 6      1960     72    96.000000       4.000000
# 7      1970     99    96.116505       3.883495
# 8      1980     90    95.744681       4.255319
# 9      1990     94    93.069307       6.930693
# 10     2000    108    90.756303       9.243697
# 11     2010    104    88.888889      11.111111
# 12     2020     29    80.555556      19.444444

# %%
countAll
# Out:
#     decades  prize
# 0      1900     56
# 1      1910     38
# 2      1920     54
# 3      1930     55
# 4      1940     40
# 5      1950     71
# 6      1960     75
# 7      1970    103
# 8      1980     94
# 9      1990    101
# 10     2000    119
# 11     2010    117
# 12     2020     36

# %%
## Plotting Q4 using stacked opposition graph.
plt.rcParams['axes.facecolor'] = '#FFFAF0'
plt.figure(figsize=(15,6))
plt.xticks(countMale['decades'])
plt.ylim(0, 100)

alpha1= 0.5
alpha2= 1.0
color1 = (186/255,85/255,211/255) #rgb color1: 
color2 = (255/255,105/255,180/255) #rgb color2: 
plt.bar(countMale['decades'], 
        countMale['malePortion'], 
        bottom=countMale['femalePortion'], 
        width=7, 
        color=color1 + (alpha1,),
        edgecolor='black',
        label='Male')
plt.bar(countMale['decades'], 
        countMale['femalePortion'],
        width=7,
        color=color2 + (alpha2,),
        edgecolor='black',
        label='Female')


plt.legend()
plt.show()

# %% [markdown]
# #Analysis.
#
#             Is there any gender imbalance in this data? How significant is that? Calculate the proportion of female laureates in each decade. Visualize your results and discuss.
#             Yes, the gender imbalance of United State's Nobel Winners has been enormous since 1900. On average, over the year span of over 120 years, only 6% of the contributors are females in each decade, and about 94% among all candidates are male. We can observe from the graph that from 1900-1910, USA had a massive decay over women nobel winners, but it has been risen over the course of the next 4 decades til 1940, the portion of female norbel winners has reached new high. After that, the female portion decreased for a few decades and then hitting another new high in the 2000s, where is the highest among all decades, which is around 10.89% in all representing winners.

# %% [markdown]
# #5. For the gender imbalance that you found in question 4, is it better or worse within specific prize categories? Visualize your results for each category and discuss. Which of them has the largest gender imbalance? Which has shown some positive trend over the decades?

# %%
dftotalw = dfFemale.groupby('category')['prize'].count().reset_index()
dftotal = df4.groupby( 'category')['prize'].count().reset_index()
dftotalw['proportion(%)'] = dftotalw['prize']/dftotal['prize']*100
dftotalw
# Out:
#                  category  prize  proportion(%)
# 0               Chemistry      8       4.188482
# 1       Economic Sciences      2       2.173913
# 2              Literature     17      14.285714
# 3                   Peace     18      16.363636
# 4                 Physics      4       1.801802
# 5  Physiology or Medicine     12       5.333333

# %%
dfAll_Sum = df4.groupby(['decades', 'category'])['prize'].count().reset_index()
dfAll_SumIndexed = dfAll_Sum.set_index(['decades'])
#catList = ['Chemistry', 'Economic Sciences', 'Literature', 'Peace', 'Physics', 'Physiology or Medicine']
dfWomen = df4[df4['gender'] == 'female']
dfWomen_Sum = dfWomen.groupby(['decades', 'category'])['prize'].count().reset_index()
## Plot all lines with subplots using different colors to represent the difference.


all_Chem = dfAll_Sum[dfAll_Sum['category'] == 'Chemistry'].set_index(['decades'])
women_Chem = dfWomen_Sum[dfWomen_Sum['category'] == 'Chemistry'].set_index(['decades'])
women_Chem_prob = women_Chem['prize']/all_Chem['prize']
women_Chem_prob = women_Chem_prob.fillna(0)



all_Econ = dfAll_Sum[dfAll_Sum['category'] == 'Economic Sciences'].set_index(['decades'])
all_Econ = all_Econ.merge(all_Chem, on='decades', how='outer').sort_values(by='decades')
all_Econ['category_x'] = all_Econ['category_x'].fillna('Economic Sciences')
all_Econ['prize_x'] = all_Econ['prize_x'].fillna(0)

women_Econ = dfWomen_Sum[dfWomen_Sum['category'] == 'Economic Sciences'].set_index(['decades'])
women_Econ_prob = women_Econ['prize']/all_Econ['prize_x']
women_Econ_prob = women_Econ_prob.fillna(0)

all_Lit = dfAll_Sum[dfAll_Sum['category'] == 'Literature'].set_index(['decades'])
women_Lit = dfWomen_Sum[dfWomen_Sum['category'] == 'Literature'].set_index(['decades'])
women_Lit_prob = women_Lit['prize']/all_Lit['prize']
women_Lit_prob = women_Lit_prob.fillna(0)

all_Peace = dfAll_Sum[dfAll_Sum['category'] == 'Peace'].set_index(['decades'])
women_Peace = dfWomen_Sum[dfWomen_Sum['category'] == 'Peace'].set_index(['decades'])
women_Peace_prob = women_Peace['prize']/all_Peace['prize']
women_Peace_prob = women_Peace_prob.fillna(0)

all_Physics = dfAll_Sum[dfAll_Sum['category'] == 'Physics'].set_index(['decades'])
women_Physics = dfWomen_Sum[dfWomen_Sum['category'] == 'Physics'].set_index(['decades'])
women_Physics_prob = women_Physics['prize']/all_Physics['prize']
women_Physics_prob = women_Physics_prob.fillna(0)

all_Med = dfAll_Sum[dfAll_Sum['category'] == 'Physiology or Medicine'].set_index(['decades'])
women_Med = dfWomen_Sum[dfWomen_Sum['category'] == 'Physiology or Medicine'].set_index(['decades'])
women_Med_prob = women_Med['prize']/all_Med['prize']
women_Med_prob = women_Med_prob.fillna(0)

# %%
x = all_Chem.index
plt.figure(figsize= (15,6))
plt.xticks(df4['decades'])
plt.xlim(1900, 2020)
# plt.ylim(0,100)
plt.plot(x, women_Chem_prob, linestyle='dashed', color='c', label='chem')
plt.plot(x, women_Econ_prob, linestyle='dashed', color='red', label='econ')
plt.plot(x, women_Lit_prob, linestyle='dashed', color='grey', label='lit')
plt.plot(x, women_Peace_prob, linestyle='dashed', color='yellow', label='peace')
plt.plot(x, women_Physics_prob, linestyle='dashed', color='orange', label='physics')
plt.plot(x, women_Med_prob, linestyle='dashed', color='green', label='med')

plt.legend()
plt.title('Female Winners % by Category')

# Display the plot
plt.grid()
plt.show()

# %% [markdown]
# #Q5 Analysis:
#
#                We find that the gender imbalance is particularly high in the physical and economic sciences categories, and to a lesser extent in the literature and peace categories. Since the 1980s, the Peace Prize, Literature Prize, and Chemistry Prize have shown positive trends, and the percentage of female winners has increased significantly.

# %% [markdown]
# #6. Are there any people who have won the Nobel Prize more than once? Who are they?

# %%
dfPrizeCount = df4.groupby(['full_name'])['prize'].count().sort_values(ascending=False).reset_index()
dfPrizeMultiple = dfPrizeCount[dfPrizeCount['prize'] > 1]
dfPrizeMultiple
# Out:
#                      full_name  prize
# 0             Frederick Sanger      2
# 1           K. Barry Sharpless      2
# 2  Marie Curie, née Sklodowska      2
# 3           Linus Carl Pauling      2
# 4                 John Bardeen      2

# %% [markdown]
#     Yes, there are a few people who has won the Nobel Prize more than once, they are Frederick Sanger, K. Barry Sharpless, Marie Curie, née Sklodowska, Linus Carl Pauling, and John Bardeen.

# %%
dfBirth
# Out:
#                               full_name birth_date  year  prize  age
# 142  Christian Matthias Theodor Mommsen 1817-11-30  1902      1   85
# 286                      Frédéric Passy 1822-05-20  1901      1   79
# 939               William Randal Cremer 1828-03-18  1903      1   75
# 439                   Jean Henry Dunant 1828-05-08  1901      1   73
# 80     Auguste Marie François Beernaert 1829-07-26  1909      1   80
# ..                                  ...        ...   ...    ...  ...
# 535                Konstantin Novoselov 1974-08-23  2010      1   36
# 7                        Abiy Ahmed Ali 1976-08-15  2019      1   43
# 866                     Tawakkol Karman 1979-07-02  2011      1   32
# 627              Nadia Murad Basee Taha 1993-01-01  2018      1   25
# 576                    Malala Yousafzai 1997-12-07  2014      1   17
#
# [959 rows x 5 columns]

# %% [markdown]
# #7. Who are the oldest and youngest people ever to have won a Nobel Prize? How old were the winners generally when they got the prize? Show the summary statistics, and plot the distribution of the age of winners.

# %%
dfBirth = df4.groupby(['full_name','birth_date','year'])['prize'].count().reset_index()
dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# Out:
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '19/06/1922' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '29/01/1926' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '21/02/1961' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '15/08/1976' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '22/06/1939' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '16/12/1969' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '24/03/1903' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '26/11/1931' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '26/02/1946' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '30/01/1948' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '15/06/1947' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '14/04/1927' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '22/01/1936' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '31/03/1948' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '25/09/1962' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '25/06/1928' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '20/03/1911' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '23/02/1924' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '31/01/1902' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '18/12/1951' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '21/10/1958' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '16/06/1965' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '21/05/1921' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '22/11/1917' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '30/11/1926' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '27/04/1959' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '19/10/1945' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '26/03/1938' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '20/05/1945' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '20/11/1940' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '26/04/1933' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '29/08/1943' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '25/01/1923' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '19/06/1945' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '31/12/1937' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '16/06/1902' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '27/01/1936' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '30/09/1951' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '28/07/1925' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '29/10/1920' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '13/12/1953' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '18/04/1949' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '21/05/1934' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '18/05/1951' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '15/07/1918' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '24/05/1941' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '30/05/1955' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '24/02/1967' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '29/12/1957' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '22/03/1931' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '26/03/1951' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '31/03/1934' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '15/04/1961' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '22/09/1901' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '28/07/1915' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '25/08/1952' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '22/09/1922' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '26/03/1916' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '20/10/1942' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '20/02/1948' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '21/10/1942' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '23/09/1915' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '18/10/1960' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '30/06/1911' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '29/07/1905' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '24/01/1941' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '23/03/1907' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '28/02/1939' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '29/07/1937' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '30/10/1928' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '24/03/1926' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '27/02/1926' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '19/02/1941' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '21/09/1934' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '24/02/1944' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '20/01/1931' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '15/10/1944' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '16/03/1968' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '23/01/1930' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '23/02/1966' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '21/09/1926' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '22/04/1919' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '27/05/1959' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '22/10/1919' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '25/10/1953' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '18/06/1932' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '15/03/1920' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '19/11/1915' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '26/07/1933' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '27/04/1962' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '20/05/1918' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '26/12/1940' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '14/12/1909' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '30/08/1912' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '18/09/1907' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '14/07/1935' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '27/03/1901' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '20/10/1946' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '25/07/1905' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '30/09/1928' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '26/11/1948' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '22/05/1943' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '29/10/1938' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '29/09/1901' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '19/12/1961' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '13/01/1960' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '19/06/1906' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '25/12/1906' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '20/03/1944' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '25/10/1972' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '14/02/1939' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '17/11/1902' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '29/07/1900' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '14/09/1951' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '28/06/1927' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '23/10/1905' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '14/09/1936' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '25/07/1956' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '18/06/1918' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '15/05/1951' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '17/06/1920' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '30/07/1947' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '25/08/1916' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '16/03/1918' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '13/08/1918' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '18/03/1936' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '19/03/1900' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '14/07/1921' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '17/06/1940' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '22/05/1927' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '19/12/1903' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '19/11/1912' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '20/02/1945' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '18/04/1905' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '17/01/1911' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '18/11/1906' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '22/10/1903' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '17/04/1946' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '20/07/1947' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '25/12/1904' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '23/01/1918' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '13/03/1900' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '26/02/1903' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '19/04/1912' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '28/08/1919' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '22/06/1944' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '21/05/1936' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '16/10/1927' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '31/08/1949' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '22/12/1903' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '23/04/1902' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '23/08/1931' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '30/05/1908' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '25/08/1900' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '18/12/1939' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '24/08/1927' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '18/07/1948' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '21/12/1917' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
# ...
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '27/09/1918' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '30/09/1905' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '25/01/1949' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '14/05/1954' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '17/08/1932' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '28/05/1942' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '17/11/1922' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '23/12/1962' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '28/02/1948' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '19/10/1910' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '20/04/1955' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '31/05/1948' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '13/01/1927' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '21/09/1931' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '27/01/1942' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '30/10/1941' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '30/04/1902' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '23/08/1940' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '14/04/1921' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '22/12/1955' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '15/06/1915' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '19/07/1943' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '19/02/1943' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '28/08/1910' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '28/01/1938' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '15/04/1931' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '18/02/1931' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '13/12/1911' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '24/11/1926' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '30/12/1930' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '18/05/1901' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '23/07/1906' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '21/03/1932' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '16/08/1904' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '29/08/1904' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '17/12/1908' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '19/08/1924' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '13/02/1910' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '28/06/1930' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '24/06/1953' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '16/06/1934' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '23/11/1957' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '19/09/1911' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '25/06/1911' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '21/06/1914' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '18/12/1913' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '13/07/1934' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '21/10/1957' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '25/04/1900' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '24/08/1929' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '18/01/1921' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_8088/175989659.py:2: UserWarning: Parsing '19/11/1936' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfBirth['birth_date'] = pd.to_datetime(dfBirth['birth_date'],infer_datetime_format=True)

# %%
dfBirth['age'] = dfBirth['year'] - dfBirth['birth_date'].dt.year
dfBirth = dfBirth.sort_values('birth_date')
dfBirth
# Out:
#                               full_name birth_date  year  prize  age
# 142  Christian Matthias Theodor Mommsen 1817-11-30  1902      1   85
# 286                      Frédéric Passy 1822-05-20  1901      1   79
# 939               William Randal Cremer 1828-03-18  1903      1   75
# 439                   Jean Henry Dunant 1828-05-08  1901      1   73
# 80     Auguste Marie François Beernaert 1829-07-26  1909      1   80
# ..                                  ...        ...   ...    ...  ...
# 535                Konstantin Novoselov 1974-08-23  2010      1   36
# 7                        Abiy Ahmed Ali 1976-08-15  2019      1   43
# 866                     Tawakkol Karman 1979-07-02  2011      1   32
# 627              Nadia Murad Basee Taha 1993-01-01  2018      1   25
# 576                    Malala Yousafzai 1997-12-07  2014      1   17
#
# [959 rows x 5 columns]

# %%
dfBirth.describe()
# Out:
#               year  prize         age
# count   959.000000  959.0  959.000000
# mean   1972.977059    1.0   60.164755
# std      34.309221    0.0   12.638046
# min    1901.000000    1.0   17.000000
# 25%    1949.000000    1.0   51.000000
# 50%    1978.000000    1.0   60.000000
# 75%    2002.000000    1.0   69.000000
# max    2022.000000    1.0   97.000000

# %% [markdown]
# #Analysis.
#
#
#         From the dataframe above, we can observe that the oldest people who ever won a Nobel's prize was Christian Matthias Theodor Mommsen who was born in 1817, he was 86 when he got his prize in 1902, and the youngest people who ever won a Nobel's prize was Malala Yousafzai who was born in 1997, in which he was only 17 years old when he received the prize in 2014. The distributions shows that 25% of the people are below or equal to 51 years old, 50% are between 51-60 years old. 75% who are below 69 years old, and the rest are the ones that's below 97 years old.

# %%
plt.hist(dfBirth['age'], bins=100, color='pink', edgecolor='black')
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# #8. For your results in question 7, does the average age of winners differ across each category? For each category, show the summary statistics and plot the distribution of the age of winners. Which categories have the largest and smallest average age of winners?
#
#
# #Anlysis:
#
#             From our results and observation from Q7 and the graph plotted below, we've found out that the average age of winners differs substantially ranging from 57.1-66.83 in age differences, the max difference is around 10 years, and the minimum difference is around 3 years across all categories. We've created and shown the summary for each category and have graphed their distribution for us to have a better understanding in detail that helps us to gain more insights to the age differences in subject's averages. From the analysis and plot, we found out the the category that has the largest average age is from Economical Sciences, and the least average is from Physics.

# %%
dfBirthCat = df4.groupby(['category','birth_date','year'])['prize'].count().reset_index()
dfBirthCat['birth_date'] = pd.to_datetime(dfBirthCat['birth_date'], format='%d/%m/%Y', errors='coerce').fillna(
    pd.to_datetime(dfBirthCat['birth_date'], format='%Y-%m-%d', errors='coerce'))
dfBirthCat['birth_year'] = dfBirthCat['birth_date'].dt.year
dfBirthCat['age'] = dfBirthCat['year'] - dfBirthCat['birth_year']

# %%
## Deriving the numbers and averages we need.

def create_average(catList, dfOrigin):
    catContainer = []
    for i in range(len(catList)):
        dataFrame = dfOrigin[dfOrigin['category'] == catList[i]]
        catContainer.append(dataFrame)
    return catContainer

catList = ['Chemistry', 'Economic Sciences', 'Literature', 'Peace', 'Physics', 'Physiology or Medicine']
dfMainCat = create_average(catList, dfBirthCat)

dfChem = dfMainCat[0]
summaryChem = dfChem.describe()
chem_average = summaryChem['age']['mean']

dfEcon = dfMainCat[1]
summaryEcon = dfEcon.describe()
econ_average = summaryEcon['age']['mean']

dfLiterature = dfMainCat[2]
summaryLiterature = dfLiterature.describe()
literature_average = summaryLiterature['age']['mean']

dfPeace = dfMainCat[3]
summaryPeace = dfPeace.describe()
peace_average = summaryPeace['age']['mean']

dfPhysics = dfMainCat[4]
summaryPhysics = dfPhysics.describe()
physics_average = summaryPhysics['age']['mean']

dfMed = dfMainCat[5]
summaryMed = dfMed.describe()
med_average = summaryMed['age']['mean']

avg_list = [chem_average, econ_average, literature_average, peace_average, physics_average, med_average]

# %%
## Plotting and Adjusting the Settings
plt.figure(figsize=(15,6))
plt.plot(catList, avg_list, label='Average Age Across Categories', linestyle = 'dotted', color='c')
plt.grid()
plt.title('Average Age All Categories')
#Placing the coordinates.
for i in range(len(catList)):
    plt.annotate('{:.2f}'.format(avg_list[i]), xy=(catList[i], avg_list[i]), xytext=(catList[i], avg_list[i] + 0.05), ha='center', va='bottom')
    

plt.legend()
plt.show()

# %%
dfChem.describe()
# Out:
#               year  prize   birth_year         age
# count   191.000000  191.0   191.000000  191.000000
# mean   1974.136126    1.0  1915.230366   58.905759
# std      34.471381    0.0    29.684646   11.847785
# min    1901.000000    1.0  1835.000000   35.000000
# 25%    1948.500000    1.0  1896.500000   50.000000
# 50%    1980.000000    1.0  1918.000000   58.000000
# 75%    2003.500000    1.0  1939.500000   68.000000
# max    2022.000000    1.0  1968.000000   97.000000

# %%
plt.figure(figsize=(15,6))
x = dfChem['age']
plt.hist(x, bins=100, color='pink', edgecolor='black', label='Average Across Chem')
plt.grid()
    
plt.title('Age Distribution Chem')
plt.legend()
plt.show()

# %%
dfEcon.describe()
# Out:
#               year  prize   birth_year        age
# count    92.000000   92.0    92.000000  92.000000
# mean   1998.293478    1.0  1931.467391  66.826087
# std      15.861723    0.0    17.900489   8.264326
# min    1969.000000    1.0  1895.000000  47.000000
# 25%    1985.750000    1.0  1917.750000  61.000000
# 50%    2000.500000    1.0  1933.000000  67.000000
# 75%    2011.250000    1.0  1944.250000  72.000000
# max    2022.000000    1.0  1972.000000  90.000000

# %%
plt.figure(figsize=(15,6))
x = dfEcon['age']
plt.hist(x, bins=100, color='yellow', edgecolor='black', label='Average Across Econ')
plt.grid()
    
plt.title('Age Distribution Econ')
plt.legend()
plt.show()

# %%
dfLiterature.describe()
# Out:
#               year  prize   birth_year         age
# count   119.000000  119.0   119.000000  119.000000
# mean   1962.445378    1.0  1897.436975   65.008403
# std      35.678816    0.0    33.905062   10.291922
# min    1901.000000    1.0  1817.000000   42.000000
# 25%    1930.500000    1.0  1869.500000   57.000000
# 50%    1965.000000    1.0  1900.000000   67.000000
# 75%    1992.500000    1.0  1926.500000   73.000000
# max    2022.000000    1.0  1962.000000   88.000000

# %%
plt.figure(figsize=(15,6))
x = dfLiterature['age']
plt.hist(x, bins=100, color='c', edgecolor='black', label='Average Across Literature')
plt.grid()
    
plt.title('Literature Distribution Age')
plt.legend()
plt.show()

# %%
dfPeace.describe()
# Out:
#               year  prize   birth_year         age
# count   110.000000  110.0   110.000000  110.000000
# mean   1963.572727    1.0  1902.709091   60.863636
# std      37.613061    0.0    43.518918   13.195410
# min    1901.000000    1.0  1822.000000   17.000000
# 25%    1927.500000    1.0  1863.250000   54.000000
# 50%    1972.000000    1.0  1909.000000   62.000000
# 75%    1995.750000    1.0  1939.500000   71.000000
# max    2022.000000    1.0  1997.000000   87.000000

# %%
plt.figure(figsize=(15,6))
x = dfPeace['age']
plt.hist(x, bins=100, color='c', edgecolor='black', label='Average Across Peace')
plt.grid()
    
plt.title('Peace Distribution Age')
plt.legend()
plt.show()

# %%
dfPhysics.describe()
# Out:
#               year  prize   birth_year         age
# count   222.000000  222.0   222.000000  222.000000
# mean   1973.090090    1.0  1915.990991   57.099099
# std      34.339943    0.0    28.670857   14.736574
# min    1901.000000    1.0  1837.000000   25.000000
# 25%    1951.250000    1.0  1901.000000   46.000000
# 50%    1978.000000    1.0  1922.000000   55.500000
# 75%    2002.000000    1.0  1935.750000   68.000000
# max    2022.000000    1.0  1974.000000   96.000000

# %%
plt.figure(figsize=(15,6))
x = dfPhysics['age']
plt.hist(x, bins=100, color='y', edgecolor='black', label='Average Across Physics')
plt.grid()
    
plt.title('Physics Distribution Age')
plt.legend()
plt.show()

# %%
dfMed.describe()
# Out:
#               year  prize   birth_year         age
# count   225.000000  225.0   225.000000  225.000000
# mean   1971.697778    1.0  1913.066667   58.631111
# std      32.145557    0.0    29.726882   11.727635
# min    1901.000000    1.0  1841.000000   32.000000
# 25%    1950.000000    1.0  1895.000000   50.000000
# 50%    1974.000000    1.0  1917.000000   57.000000
# 75%    1999.000000    1.0  1937.000000   67.000000
# max    2022.000000    1.0  1967.000000   87.000000

# %%
plt.figure(figsize=(15,6))
x = dfMed['age']
plt.hist(x, bins=100, color='purple', edgecolor='black', label='Average Across Med')
plt.grid()
    
plt.title('Med Distribution Age')
plt.legend()
plt.show()

# %% [markdown]
# #9. Make some plots to visualize the time trend of the average age of winners in each specific category per decade. What do you find?

# %%
#'Chemistry'
dfChem['decades'] = (dfChem['year']//10)*10
dfChemAvg = dfChem.groupby(['decades'])['age'].mean().reset_index()
dfChemAvg

#Plotting
x = dfChemAvg['decades']
y = dfChemAvg['age']
plt.figure(figsize=(15,6))
plt.plot(x,y, color='c')
plt.grid()
plt.title('Average Age through Decades- Chem')
# Out:
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_7786/2382498475.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfChem['decades'] = (dfChem['year']//10)*10
# Text(0.5, 1.0, 'Average Age through Decades- Chem')

# %% [markdown]
# #Analysis:
#
#             I found that from the Chem Category, the average age of Nobel Prize Winners are slowly risen. In 1900, the average age of normal Nobel prize's winner is around 52 years old. However, at 1960, it was around 56, 1970 approches 63, and increasing about 5 age range per decades till 2010 and 2020.

# %%
#'Economic Sciences', 
dfEcon['decades'] = (dfEcon['year']//10)*10
dfEconAvg = dfEcon.groupby(['decades'])['age'].mean().reset_index()
dfEconAvg

#Plotting
x = dfEconAvg['decades']
y = dfEconAvg['age']
plt.figure(figsize=(15,6))
plt.plot(x,y, color='r')
plt.grid()
plt.title('Average Age through Decades- Econ')
# Out:
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_7786/2715828653.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfEcon['decades'] = (dfEcon['year']//10)*10
# Text(0.5, 1.0, 'Average Age through Decades- Econ')

# %% [markdown]
# #Analysis:
#
#             I found that from the Economics Category, the average of winning the nobel prize decays from 1960 to 1990, where I assume in this amount of time, a lot of new Economist with Nobel prize were born prior with earlier age. However, after the 1990 pivot, the average age of Economics Nobel Prize winners increased again from below age 66 to age 68.

# %%
##Literature
dfLiterature['decades'] = (dfLiterature['year']//10)*10
dfLitAvg = dfLiterature.groupby(['decades'])['age'].mean().reset_index()
dfLitAvg

#Plotting
x = dfLitAvg['decades']
y = dfLitAvg['age']
plt.figure(figsize=(15,6))
plt.plot(x,y, color='brown')
plt.grid()
plt.title('Average Age through Decades- Literature')
# Out:
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_7786/1971126795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfLiterature['decades'] = (dfLiterature['year']//10)*10
# Text(0.5, 1.0, 'Average Age through Decades- Literature')

# %% [markdown]
# #Analysis:
#
#             I found that from the Literature Category have also been risen in average age as well, and I think that the main reason for people to obtain Nobel prize late is because of the amount of systematic change we had during these 12 decades. From 1900- 2020, our life and surroundings have changed dramatically, we have been shifting from the industrial revolution where people has mass amount of pressure and dissatisfaction from the society to a decade where people mostly used technologies and are be surrounded by type of environment that is recaptured by social media, fast foods, and consumer products. Thus, it requries us more time and effort to be able to practice and perform in literature.

# %%
##Peace

dfPeace['decades'] = (dfPeace['year']//10)*10
dfPeaceAvg = dfPeace.groupby(['decades'])['age'].mean().reset_index()
dfPeaceAvg


#Plotting
x = dfPeaceAvg['decades']
y = dfPeaceAvg['age']
plt.figure(figsize=(15,6))
plt.plot(x,y, color='teal')
plt.grid()
plt.title('Average Age through Decades- Peace')
# Out:
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_7786/3803901659.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfPeace['decades'] = (dfPeace['year']//10)*10
# Text(0.5, 1.0, 'Average Age through Decades- Peace')

# %% [markdown]
# #Analysis:
#
#             I found that however, for the peace category, the average age has becoming a decay over the years. While from 1900 - 2910, the average age is about 64-67 years old, hitting a climax at 76 years old at 1940, however, after 1940, a serious of decrease occured. While, in 1980 the average age is about 56, and around 2010, the average age is long below 50. I believe that this is also important due to our shift of our political and social economical systems. While more people are getting affordable housing, pricing, and proper management. The level of civilization has increased, thus, people who works and contribute in peace industry are more willing to contribute due to enormous amount of funds flowing into the industry.

# %%
## Physics
dfPhysics['decades'] = (dfPhysics['year']//10)*10
dfPhyAvg = dfPhysics.groupby(['decades'])['age'].mean().reset_index()
dfPhyAvg

#Plotting
x = dfPhyAvg['decades']
y = dfPhyAvg['age']
plt.figure(figsize=(15,6))
plt.plot(x,y, color='gold')
plt.grid()
plt.title('Average Age through Decades- Physics')
# Out:
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_7786/3860715034.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfPhysics['decades'] = (dfPhysics['year']//10)*10
# Text(0.5, 1.0, 'Average Age through Decades- Physics')

# %% [markdown]
# #Analysis:
#
#             I found that from the Physics category, the average amount of age of Nobel prize winners has been risen over an almost linear slope. This is strongly due to the difficulty level of coming up with new physics theories. While the most brand span physics theory are settled already based on Einstein and Newton, new discoveries and insights are being posted day to day. However, based on the improvement of technology and all different types of accessories inside the indsutry, the average age of Physics Nobel Prize winners has been largely delayed.

# %%
##Medicine

dfMed['decades'] = (dfMed['year']//10)*10
dfMedAvg = dfMed.groupby(['decades'])['age'].mean().reset_index()
dfMedAvg

#Plotting
x = dfMedAvg['decades']
y = dfMedAvg['age']
plt.figure(figsize=(15,6))
plt.plot(x,y, color='green')
plt.grid()
plt.title('Average Age through Decades- Med')
# Out:
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_7786/3087806752.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfMed['decades'] = (dfMed['year']//10)*10
# Text(0.5, 1.0, 'Average Age through Decades- Med')

# %% [markdown]
# #Analysis:
#
#             I found that the med industry has the similarity that share with a physics Nobel winner. We can see that as the time approaches more to the modern time, the average age of Med Nobel winner has been delayed from 56 - 67 by almost 10 years as well. Indeed, I believe the conclusion has came with the same as the physics industry, while modern medicine and physics are already based on a variety of settings and variety of pre-exisiting theories, thus, causing the increment to speed up.

# %% [markdown]
# #10. Repeat the analysis in question 9, but with lifespan instead of age. What do you find?

# %%
col = ['year','category','birth_date','death_date']
dfls = df[col].dropna() 
dfls['decades'] = (dfls['year']// 10)* 10
dfls['lifespan'] = (dfls['death_date'].str[0:4].astype(int)) - (dfls['birth_date'].str[0:4].astype(int))
dfls
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_7786/1915508847.py in <module>
#       2 dfls = df[col].dropna()
#       3 dfls['decades'] = (dfls['year']// 10)* 10
# ----> 4 dfls['lifespan'] = (dfls['death_date'].str[0:4].astype(int)) - (dfls['birth_date'].str[0:4].astype(int))
#       5 dfls
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     302                     applied = b.apply(f, **kwargs)
#     303                 else:
# --> 304                     applied = getattr(b, f)(**kwargs)
#     305             except (TypeError, NotImplementedError):
#     306                 if not ignore_failures:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     578         values = self.values
#     579
# --> 580         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     581
#     582         new_values = maybe_coerce_values(new_values)
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1290
#    1291     try:
# -> 1292         new_values = astype_array(values, dtype, copy=copy)
#    1293     except (ValueError, TypeError):
#    1294         # e.g. astype_nansafe can fail on object-dtype of strings
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1235
#    1236     else:
# -> 1237         values = astype_nansafe(values, dtype, copy=copy)
#    1238
#    1239     # in pandas we don't store numpy str dtypes, so convert to object
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1152         # work around NumPy brokenness, #1987
#    1153         if np.issubdtype(dtype.type, np.integer):
# -> 1154             return lib.astype_intsafe(arr, dtype)
#    1155
#    1156         # if we have a datetime/timedelta array of objects
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '01/0'

# %%
dfLifespan = dfls.groupby(['category','decades'])['lifespan'].mean().reset_index()
dfLifespan
# Out:
#                   category  decades   lifespan
# 0                Chemistry     1900  66.333333
# 1                Chemistry     1910  68.875000
# 2                Chemistry     1920  76.500000
# 3                Chemistry     1930  73.461538
# 4                Chemistry     1940  80.444444
# ..                     ...      ...        ...
# 61  Physiology or Medicine     1970  83.150000
# 62  Physiology or Medicine     1980  85.500000
# 63  Physiology or Medicine     1990  87.222222
# 64  Physiology or Medicine     2000  87.625000
# 65  Physiology or Medicine     2010  78.000000
#
# [66 rows x 3 columns]

# %%
dfChemspan = dfLifespan[dfLifespan['category'] == 'Chemistry']
dfChemspan
# Out:
#      category  decades   lifespan
# 0   Chemistry     1900  66.333333
# 1   Chemistry     1910  68.875000
# 2   Chemistry     1920  76.500000
# 3   Chemistry     1930  73.461538
# 4   Chemistry     1940  80.444444
# 5   Chemistry     1950  82.357143
# 6   Chemistry     1960  80.333333
# 7   Chemistry     1970  83.466667
# 8   Chemistry     1980  88.909091
# 9   Chemistry     1990  82.733333
# 10  Chemistry     2000  83.666667
# 11  Chemistry     2010  85.000000

# %%
#Plotting 
x = dfChemspan['decades']
y = dfChemspan['lifespan']
plt.figure(figsize=(15,6))
plt.grid()
plt.plot(x, y, color='c', label='avg lifespan')
plt.title('Average Lifespan in Chemistry')
plt.legend()
plt.show()

# %% [markdown]
# #Analysis:
#
#             We find that, except in the 1900s and 1910s, the average lifespan of chemistry prize winners is over 70 years, and the trend is increasing.

# %%
dfEconspan = dfLifespan[dfLifespan['category'] == 'Economic Sciences']
dfEconspan
# Out:
#              category  decades   lifespan
# 12  Economic Sciences     1960  84.500000
# 13  Economic Sciences     1970  86.800000
# 14  Economic Sciences     1980  87.111111
# 15  Economic Sciences     1990  86.454545
# 16  Economic Sciences     2000  84.400000
# 17  Economic Sciences     2010  84.000000

# %%
#Plotting 
x = dfEconspan['decades']
y = dfEconspan['lifespan']
plt.figure(figsize=(15,6))
plt.grid()
plt.plot(x, y, color='c', label='avg lifespan')
plt.title('Average Lifespan in Econ')
plt.legend()
plt.show()

# %% [markdown]
# #Analysis:
#
#           The lifespan of the winners of the economic science prize is relatively large, reaching a peak of 87.11 years for the winners in the 1980s; it then fell back, and for the winners of the 2010s, their lifespan only reached 84 years old.

# %%
dfLitspan = dfLifespan[dfLifespan['category'] == 'Literature']
dfLitspan
# Out:
#       category  decades   lifespan
# 18  Literature     1900  77.500000
# 19  Literature     1910  80.111111
# 20  Literature     1920  78.100000
# 21  Literature     1930  72.222222
# 22  Literature     1940  75.666667
# 23  Literature     1950  77.600000
# 24  Literature     1960  77.636364
# 25  Literature     1970  80.727273
# 26  Literature     1980  85.000000
# 27  Literature     1990  86.700000
# 28  Literature     2000  86.250000
# 29  Literature     2010  84.000000

# %%
#Plotting 
x = dfLitspan['decades']
y = dfLitspan['lifespan']
plt.figure(figsize=(15,6))
plt.grid()
plt.plot(x, y, color='c', label='avg lifespan')
plt.title('Average Lifespan in Lit')
plt.legend()
plt.show()

# %% [markdown]
# #Analysis:
#
#            The lifespan of a literary award winner fluctuates widely. The average lifespan of the winners in the 1930s was only 72.2 years old, and then rose all the way. The average lifespan of the winners after the 1980s was over 84 years old

# %%
dfPeacespan = dfLifespan[dfLifespan['category'] == 'Peace']
dfPeacespan
# Out:
#    category  decades   lifespan
# 30    Peace     1900  76.923077
# 31    Peace     1910  76.200000
# 32    Peace     1920  73.909091
# 33    Peace     1930  77.000000
# 34    Peace     1940  89.750000
# 35    Peace     1950  76.857143
# 36    Peace     1960  69.200000
# 37    Peace     1970  78.500000
# 38    Peace     1980  85.500000
# 39    Peace     1990  85.555556
# 40    Peace     2000  78.333333
# 41    Peace     2010  62.000000

# %%
#Plotting 
x = dfPeacespan['decades']
y = dfPeacespan['lifespan']
plt.figure(figsize=(15,6))
plt.grid()
plt.plot(x, y, color='c', label='avg lifespan')
plt.title('Average Lifespan in Peace')
plt.legend()
plt.show()

# %% [markdown]
# #Analysis:
#
#            The average lifespan of the Peace Prize winners varies greatly and is irregular. The maximum value appeared in the winners in the 1940s, which was 89.75 years old; the minimum value appeared in the winners in the 2010s, who were only 62 years old.

# %%
dfPhysicspan = dfLifespan[dfLifespan['category'] == 'Physics']
dfPhysicspan
# Out:
#    category  decades   lifespan
# 42  Physics     1900  71.769231
# 43  Physics     1910  77.200000
# 44  Physics     1920  82.000000
# 45  Physics     1930  75.727273
# 46  Physics     1940  76.000000
# 47  Physics     1950  81.166667
# 48  Physics     1960  80.058824
# 49  Physics     1970  85.411765
# 50  Physics     1980  87.277778
# 51  Physics     1990  82.700000
# 52  Physics     2000  88.076923
# 53  Physics     2010  91.666667

# %%
#Plotting 
x = dfPhysicspan['decades']
y = dfPhysicspan['lifespan']
plt.figure(figsize=(15,6))
plt.grid()
plt.plot(x, y, color='red', label='avg lifespan')
plt.title('Average Lifespan in Physics')
plt.legend()
plt.show()

# %% [markdown]
# #Analysis:
#
#             The average lifespan in Physics was kind of weird since in 1920 it was 82, and in 1930 and 1940 there was only 76 years old. I believe that there was not so much info about the years in 1920, thus, the extreme value corrupted the current trend. However, we can see that from the rise of 1930-1960, the average lifespan had increased decades over decades from 76 yo to 80yo.

# %%
dfMedspan = dfLifespan[dfLifespan['category'] == 'Physiology or Medicine']
dfMedspan
# Out:
#                   category  decades   lifespan
# 54  Physiology or Medicine     1900  71.454545
# 55  Physiology or Medicine     1910  74.833333
# 56  Physiology or Medicine     1920  71.000000
# 57  Physiology or Medicine     1930  83.785714
# 58  Physiology or Medicine     1940  79.000000
# 59  Physiology or Medicine     1950  83.500000
# 60  Physiology or Medicine     1960  84.250000
# 61  Physiology or Medicine     1970  83.150000
# 62  Physiology or Medicine     1980  85.500000
# 63  Physiology or Medicine     1990  87.222222
# 64  Physiology or Medicine     2000  87.625000
# 65  Physiology or Medicine     2010  78.000000

# %%
#Plotting 
x = dfMedspan['decades']
y = dfMedspan['lifespan']
plt.figure(figsize=(15,6))
plt.grid()
plt.plot(x, y, color='green', label='avg lifespan')
plt.title('Average Lifespan in Med')
plt.legend()
plt.show()

# %% [markdown]
# #Analysis:
#
#             The average lifespan in Med was usually very high since medicine and physicts takes great care of their body, and the average has also been increase from 72 yo to 88 yo, despite a significant drop for the 2000s winners.

# %%
## Total Plotting
plt.figure(figsize=(15,6))
#Plotting 
xChem = dfChemspan['decades']
yChem = dfChemspan['lifespan']
plt.plot(xChem, yChem, color='purple', label='avg lifespan-chem')


xEcon = dfEconspan['decades']
yEcon = dfEconspan['lifespan']
plt.plot(xEcon, yEcon, color='gold', label='avg lifespan-econ')

xLit = dfLitspan['decades']
yLit = dfLitspan['lifespan']
plt.plot(xLit, yLit, color='brown', label='avg lifespan-peace')

xPeace = dfPeacespan['decades']
yPeace = dfPeacespan['lifespan']
plt.plot(xPeace, yPeace, color='c', label='avg lifespan-peace')

xPhysics = dfPhysicspan['decades']
yPhysics = dfPhysicspan['lifespan']
plt.plot(xPhysics, yPhysics, color='red', label='avg lifespan-physics')

xMed = dfMedspan['decades']
yMed = dfMedspan['lifespan']
plt.plot(xMed, yMed, color='green', label='avg lifespan-med')

plt.xticks(xChem)
plt.ylim(0,100)
plt.title('Average Lifespan in Med')
plt.legend()
plt.grid()
plt.show()
