# %%
import pandas as pd
import numpy as np

df = pd.read_excel('Class 21 - Valuation of Solar Corp.xlsx')
# Out:
#    Valuation of Solar Corp using VC Method for startups  Unnamed: 1  \
# 0   Solar Corp is developing a new clean-energy te...           NaN
# 1   Solar needs $100M from VC investors to continu...           NaN
# 2                   Solar's founders own 100M shares.           NaN
# 3   Risky Capital must value Solar, decide whether...           NaN
# 4   Risky Capital would provide the funds today an...           NaN
# 5   Risky Capital uses a discount rate of 30%; it ...           NaN
# 6    Note: no debt financing throughout this exercise           NaN
# 7                                                 NaN           NaN
# 8                     Projected exit value in year 5:           NaN
# 9                                   Projected NI ($M)           NaN
# 10                                  Assumed exit P/E            NaN
# 11                          Projected exit value ($M)           NaN
# 12                                                NaN           NaN
# ...
